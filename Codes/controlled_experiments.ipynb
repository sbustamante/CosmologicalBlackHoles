# %% [markdown]
# # Dynamical Friction in Hernquist Profiles

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
#==================================================================================================
#Importing all libraries
#==================================================================================================
# %matplotlib inline
from IPython.display import HTML
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation
import matplotlib.image as mpimg
import numpy as np
import subprocess
import os
import h5py

#from scripts.dynamical_friction import *
execfile( './scripts/dynamical_friction.py' )

#Data folder
DataFolder = '/home/bustamsn/PhD/Data/hernquist_dynamical_friction/'
#Results folder
DataResults = './results/'
#Loaddata flag
LoadData = True
#Maximum snapshot number
max_snap = 400

# %% [markdown]
# # Contents

# %% [markdown]
# - [Simulated Hernquist Halos](#Simulated-Hernquist-Halos)
#      - [Trajectories in geometric center frame](#Trajectories-in-geometric-center-frame)
#      - [Trajectories in potential minimum frame](#Trajectories-in-potential-minimum-frame)
# - [Analytical Friction Models](#Analytical-Friction-Models)
#      - [Chandrasekhar friction force](#Chandrasekhar-friction-force)
#      - [Drag friction force - overdamping](#Drag-friction-force---overdamping)
# - [Unimportant Tests](#Tests)

# %% [markdown]
# - - -

# %% [markdown]
# # Simulated Hernquist Halos

# %% [markdown]
# ** Description: ** set of simulations using a Hernquist profile for the dark matter halo. Parameters of Hernquist profile are:
#
# | **Parameter**        |  **Value**       |
# | -------------------- | ---------------- |
# | concentration $c$    |  $9$             |
# | virial vel $v_{200}$ | $200$ km/s       |
# | virial mass $M_{200}$| $186\ M_{\odot}$ |
# | length scale $a$     | $22.22$ kpc      |
#
# For each simulation a BH of mass $M_{BH} = 1\times10^8\ M_{\odot}$ is placed from the beginning in circular orbit at $2$ kpc from the galaxy center. In order to capture the numerical convergence of dynamical friction, different resolutions are used for dark matter particles.
#
# *Note: due to accretion physics of the BH in arepo, a set of gas particles has been placed as well, however, the gas mass fraction is almost neglectable compared with DM mass.*
#
# <br><br>
#
# **Parameters of simulations:**
#
# | **Simulation**        | $N_{DM}$      | $N_{gas}$     | $m_{DM} [M_{\odot}]$  | $m_{gas} [M_{\odot}]$ | $m_{DM}/M_{BH}$ | **DF scheme** |
# | --------------------- | ------------- | --------------| --------------------- | --------------------- | --------------- | ------------- |
# | hernq_kick_BH_1e5     | $1\times10^5$ | $1\times10^5$ | $1.858\times 10^7$    | $1.860\times 10^4$    | $0.1858$        | None          |
# | hernq_kick_BH_1e6     | $1\times10^6$ | $1\times10^6$ | $1.858\times 10^6$    | $1.860\times 10^3$    | $0.0186$        | None          |
# | hernq_drag_BH_1e5     | $1\times10^5$ | $1\times10^5$ | $1.858\times 10^7$    | $1.860\times 10^4$    | $0.1858$        | Drag force    |
# | hernq_drag_BH_1e6     | $1\times10^6$ | $1\times10^6$ | $1.858\times 10^6$    | $1.860\times 10^3$    | $0.0186$        | Drag force    |
#
#
# <br><br>
#
# Also, a convergence study is perform for the higher resolution
#
# **Convergence study:**
#
# | **Simulation**        | **ErrTolTheta** | **ErrTolForceAcc** | **ErrTolIntAccuracy** | **MaxSizeTimestep** |
# | --------------------- | --------------- | ------------------ | --------------------- | ------------------- |
# | hernq_kick_BH_1e6     | $0.7$           | $0.0025$           | $0.012$               | $0.0025$            |
# | hernq_kick_BH_1e6_T1  | $0.4$           | $0.00025$          | $0.012$               | $0.0025$            |
# | hernq_kick_BH_1e6_T2  | $0.7$           | $0.0025$           | $0.003$               | $0.0012$            |

# %% [markdown]
# * Resolution $1\times 10^5$

# %%
bh_s15 = black_hole_sim( simulation = 'hernq_kick_BH_1e5', 
                         snapbase = 'snapshot',
                         n_snap = max_snap,
                         datafolder = DataFolder,
                         resultsfolder = DataResults,
                         center = [250,250,250] )
if LoadData:
    bh_s15.load_trajectory( )
else:
    bh_s15.read_trajectory( )

# %%
bh_s25 = black_hole_sim( simulation = 'hernq_drag_BH_1e5', 
                         snapbase = 'snapshot',
                         n_snap = max_snap,
                         datafolder = DataFolder,
                         resultsfolder = DataResults,
                         center = [250,250,250] )
if LoadData:
    bh_s25.load_trajectory( )
else:
    bh_s25.read_trajectory( )

# %% [markdown]
# * Resolution $1\times 10^6$

# %%
bh_s16 = black_hole_sim( simulation = 'hernq_kick_BH_1e6', 
                         snapbase = 'snapshot',
                         n_snap = max_snap,
                         datafolder = DataFolder,
                         resultsfolder = DataResults,
                         center = [250,250,250] )
if LoadData:
    bh_s16.load_trajectory( )
else:
    bh_s16.read_trajectory( )

# %%
bh_s26 = black_hole_sim( simulation = 'hernq_drag_BH_1e6', 
                         snapbase = 'snapshot',
                         n_snap = max_snap,
                         datafolder = DataFolder,
                         resultsfolder = DataResults,
                         center = [250,250,250] )
if LoadData:
    bh_s26.load_trajectory( )
else:
    bh_s26.read_trajectory( )

# %% [markdown]
# * Convergence

# %%
bh_s16_1 = black_hole_sim( simulation = 'hernq_kick_BH_1e6_T1', 
                         snapbase = 'snapshot',
                         n_snap = max_snap,
                         datafolder = DataFolder,
                         resultsfolder = DataResults,
                         center = [250,250,250] )
if LoadData:
    bh_s16_1.load_trajectory( )
else:
    bh_s16_1.read_trajectory( )

# %%
bh_s16_2 = black_hole_sim( simulation = 'hernq_kick_BH_1e6_T2', 
                         snapbase = 'snapshot',
                         n_snap = max_snap,
                         datafolder = DataFolder,
                         resultsfolder = DataResults,
                         center = [250,250,250] )
if LoadData:
    bh_s16_2.load_trajectory( )
else:
    bh_s16_2.read_trajectory( )

# %% [markdown]
# ## Trajectories in geometric center frame

# %% [markdown]
# Each trajectory is plotted in the next figure. The lower resolution is quite noisy as the mass ratio of the DM particles to the BH is just $1:5$. The higher resolution exhibit a spiraling movement, as expected from dynamical friction.
# Regarding the convergence study, some orbits are off-center as the center of the box has been taken as reference system.

# %%
plt.figure( figsize=(16,8) )
plt.subplot(1,2,1)

#Simulated trajectories
T = max_snap
plt.plot( bh_s16.r[:T,0], bh_s16.r[:T,1] , '-', lw=2, color = 'black', label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.r[:T,0], bh_s26.r[:T,1] , '-', lw=2, color = 'gray', label = 'hernq_drag_BH_1e6' )

dL = 4
plt.xlim( (-dL,dL) )
plt.ylim( (-dL,dL) )
plt.xlabel( "$x$ [kpc]", fontsize = 18 )
plt.ylabel( "$y$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Orbit of the SMBH", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

plt.subplot(1,2,2)

#Simulated trajectories
plt.plot( bh_s15.t[:T], bh_s15.rm[:T], '--', lw=1, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e5' )
plt.plot( bh_s25.t[:T], bh_s25.rm[:T], '--', lw=1, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e5' )

plt.plot( bh_s16.t[:T], bh_s16.rm[:T], '-', lw=2, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.t[:T], bh_s26.rm[:T], '-', lw=2, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e6' )

#T = 150
#plt.plot( bh_s16_1.t[:T], bh_s16_1.rm[:T], '-.', lw=1, color = 'red', zorder = 0, label = 'hernq_kick_BH_1e6_T1' )
#plt.plot( bh_s16_2.t[:T], bh_s16_2.rm[:T], '--', lw=1, color = 'red', zorder = 0, label = 'hernq_kick_BH_1e6_T2' )

#Format
plt.ylim( (0,3) )
plt.xlim( (0,1) )
plt.xlabel( "$t$ [Gyr]", fontsize = 18 )
plt.ylabel( "$r$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Distance to the center", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

# %% [markdown]
# ## Trajectories in potential minimum frame

# %% [markdown]
# Taking the potential minimum as center of the reference system, the next figure is obtained:

# %%
plt.figure( figsize=(16,8) )
plt.subplot(1,2,1)

#Simulated trajectories
T = max_snap
plt.plot( bh_s16.r_c[:T,0], bh_s16.r_c[:T,1] , '-', lw=2, color = 'black', label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.r_c[:T,0], bh_s26.r_c[:T,1] , '-', lw=2, color = 'gray', label = 'hernq_drag_BH_1e6' )

dL = 4
plt.xlim( (-dL,dL) )
plt.ylim( (-dL,dL) )
plt.xlabel( "$x$ [kpc]", fontsize = 18 )
plt.ylabel( "$y$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Orbit of the SMBH", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

plt.subplot(1,2,2)

#Simulated trajectories
plt.plot( bh_s15.t[:T], bh_s15.rm_c[:T], '--', lw=1, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e5' )
plt.plot( bh_s25.t[:T], bh_s25.rm_c[:T], '--', lw=1, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e5' )

plt.plot( bh_s16.t[:T], bh_s16.rm_c[:T], '-', lw=2, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.t[:T], bh_s26.rm_c[:T], '-', lw=2, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e6' )

plt.plot( bh_s16_1.t[:T], bh_s16_1.rm_c[:T], '-.', lw=1, color = 'red', zorder = 2, label = 'hernq_kick_BH_1e6_T1' )
plt.plot( bh_s16_2.t[:T], bh_s16_2.rm_c[:T], '--', lw=1, color = 'red', zorder = 2, label = 'hernq_kick_BH_1e6_T2' )

#Format
plt.ylim( (0,3) )
plt.xlim( (0,1) )
plt.xlabel( "$t$ [Gyr]", fontsize = 18 )
plt.ylabel( "$r$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Distance to the center", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

# %% [markdown]
# ## Trajectories in corrected potential minimum frame

# %% [markdown]
# Taking the potential minimum as center of the reference system, but subtracting the potential due to the BH, the next figure is obtained:

# %%
plt.figure( figsize=(16,8) )
plt.subplot(1,2,1)

#Simulated trajectories
T = max_snap
plt.plot( bh_s16.r_c[:T,0], bh_s16.r_c[:T,1] , '-', lw=2, color = 'black', label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.r_c[:T,0], bh_s26.r_c[:T,1] , '-', lw=2, color = 'gray', label = 'hernq_drag_BH_1e6' )

dL = 4
plt.xlim( (-dL,dL) )
plt.ylim( (-dL,dL) )
plt.xlabel( "$x$ [kpc]", fontsize = 18 )
plt.ylabel( "$y$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Orbit of the SMBH", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

plt.subplot(1,2,2)

#Simulated trajectories
plt.plot( bh_s15.t[:T], bh_s15.rm_c[:T], '--', lw=1, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e5' )
plt.plot( bh_s25.t[:T], bh_s25.rm_c[:T], '--', lw=1, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e5' )

plt.plot( bh_s16.t[:T], bh_s16.rm_c[:T], '-', lw=2, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.t[:T], bh_s26.rm_c[:T], '-', lw=2, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e6' )

#Format
plt.ylim( (0,3) )
plt.xlim( (0,1) )
plt.xlabel( "$t$ [Gyr]", fontsize = 18 )
plt.ylabel( "$r$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Distance to the center", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

# %% [markdown]
# ## Potential minimum trajectory

# %% [markdown]
# The trajectories of the potential minima are shown in the next figure.

# %%
plt.figure( figsize=(16,16) )
fig = plt.subplot(2,1,1, projection='3d')

#Simulated trajectories
T = max_snap
#fig.plot( bh_s16.r_mp[:T,0], bh_s16.r_mp[:T,1], bh_s16.r_mp[:T,2], '-', lw=2, color = 'black', label = 'hernq_kick_BH_1e6' )
fig.plot( bh_s26.r_mp[:T,0], bh_s26.r_mp[:T,1], bh_s26.r_mp[:T,2], '-', lw=2, color = 'gray', label = 'hernq_drag_BH_1e6' )

dL = 1.
fig.set_xlim( (-dL,dL) )
fig.set_ylim( (-dL,dL) )
fig.set_zlim( (-dL/3,dL/3) )
fig.set_xlabel( "$x$ [kpc]", fontsize = 18 )
fig.set_ylabel( "$y$ [kpc]", fontsize = 18 )
fig.set_zlabel( "$z$ [kpc]", fontsize = 18 )
plt.grid(1)
fig.set_title( "Orbit of the Potential Minima", fontsize = 18 )

plt.subplot(2,1,2)

#Simulated trajectories
#plt.plot( bh_s15.t[:T], bh_s15.rm_mp[:T], '--', lw=1, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e5' )
#plt.plot( bh_s25.t[:T], bh_s25.rm_mp[:T], '--', lw=1, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e5' )

plt.plot( bh_s16.t[:T], bh_s16.rm_mp[:T], '.-', lw=2, color = 'black', zorder = 0, label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.t[:T], bh_s26.rm_mp[:T], '.-', lw=2, color = 'gray', zorder = 0, label = 'hernq_drag_BH_1e6' )

#Format
#plt.ylim( (0,2) )
plt.xlim( (0,1) )
plt.xlabel( "$t$ [Gyr]", fontsize = 18 )
plt.ylabel( "$r$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Distance to the center", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

# %% [markdown]
# ## Correction of potential minimum trajectory

# %% [markdown]
# From the previous figures, the trajectory of potential minima are quite noisy due to the limited spatial resolution at the center of galaxies.
# In order to solve this, the next corrector method is proposed:
#
# - Evaluating the numerical derivative, using a $n$-degree method of a set points $\{ \vec{r}_{i-n}, \vec{r}_{i-n+1}, \cdots, \vec{r}_{i} \}$, the following two points of the trajectory are predicted as $\vec{r}'_{i+1}$ and $\vec{r}'_{i+2}$.
# - The standard deviation of the set $\{ \vec{r}_{i-n}, \cdots, \vec{r}_{i} \}$ is defined as $\Delta\vec{r}_i$.
# - Next, the $i+1$-th and $i+2$-th real points are compared with the predicted ones.
#   - If $|(\vec{r}_{i+1} - \vec{r}'_{i+1})_j| \leq |(\Delta\vec{r}_i)_j|$, the point is included. *Note:* $j = x, y, z$.
#   - If $|(\vec{r}_{i+1} - \vec{r}'_{i+1})_j| \geq |(\Delta\vec{r}_i)_j|$ and $|(\vec{r}_{i+2} - \vec{r}'_{i+2})_j| \geq |(\Delta\vec{r}_i)_j|$, the point is included.
#   - If $|(\vec{r}_{i+1} - \vec{r}'_{i+1})_j| \geq |(\Delta\vec{r}_i)_j|$ and $|(\vec{r}_{i+2} - \vec{r}'_{i+2})_j| \leq |(\Delta\vec{r}_i)_j|$, the point is replaced by $\vec{r}'_{i+1}$.
# - This is repeated for all points.

# %% [markdown]
# - - -

# %% [markdown]
# # Analytical Friction Models

# %% [markdown]
# For comparison with analytic dynamical friction formulas, a Hernquist profile with the same parameters is created.
# The next case is studied:
#
# * A BH of mass $1 \times 10^8\ M_{\odot}$ with circular orbit at $2$ kpc.
#
# Two dynamical friction prescription are implemented: Chandrasekhar formula and efective drag friction.

# %%
#PARAMETERS OF HERNQUIST HALO
c = 9.0                             #Concentration parameter
v200 = 200.0						#Virial velocity of the halo

M = v200**3/43007.105732			#Total halo mass [1e10 M_sun]
R200 = v200						    #Virial radius [kpc]
a = R200/c

hernquist = hernquist_sphere( M, a )

# %% [markdown]
# ## Chandrasekhar friction force

# %% [markdown]
# For this case, the Chandrasekhar formula is used with the properties of a Hernquist profile:
#
# $$ M_{BH}\frac{d \vec{v}_{BH}}{dt} = -16 \pi \ln(\Lambda) G^2 M_{BH}^2\left[ \int_0^{v_M}dv v^2 f_{hern}(v) \right] \frac{\vec{v}_{BH}}{ v_{BH}^3 } $$
#
# where the distribution function of a Hernquist profile is given by [Hernquist, 1990]:
#
# $$ f_{hern}(q) = \frac{M}{8 \sqrt{2}\pi^3 a^3 v_g^3} \frac{1}{(1-q^2)^{5/2}}\times [ 3 \sin^{-1}q + q(1-q^2)^{1/2}( 1-2q^2 )( 8q^4 - 8q^2 - 3 ) ] $$
#
# and
#
# $$ q = \sqrt{ -\frac{a}{GM}E } $$
#
# $$ v_g = \left( \frac{GM}{a} \right)^{1/2}  $$
#
# $$ E = E(r, v) = \frac{1}{2}v^2 + \Phi_{hern}(r) $$
#
# The Coulomb logarithm is given by [Just, et al., 2011]:
#
# $$ \ln(\Lambda) \approx \frac{b_{max}}{ a_{90} } $$
#
# which is valid for point-like bodies like a SMBH. We adopt here the maximum impact parameters to be the local scale lenght of the density field, as suggested by (Just, et al. 2011):
#
# $$ b_{max} = \frac{\rho_{hern}}{ \left| d \rho_{hern}/dr \right|} = \frac{r(r + a)}{4r + a} $$
#
# For the $90^o$-defelction distance we use [Tremmel, 2015]:
#
# $$ a_{90} = \frac{GM_{BH}}{v^2_{BH}} $$

# %%
#PARAMETERS OF CHANDRASEKHAR FORCE
#Mass of black hole [1e10 M_sun]
Mb = 1e-2

#Distribution function
hernquist.kargs = { 'Mb':Mb }

# %%
#PARAMETERS OF THE BH
#Initial position [kpc]
r0 = [ 2, 0, 0 ]
#Initial velocity [km/s]
v0 = [ 0, hernquist.v_circular(2) , 0 ]
#Accretion mode
acc = None
#Forces
force = lambda r, v=None, t=None: hernquist.force_hernquist( r, v, t ) + hernquist.chandrasekhar_friction( r, v, t )

BHC1 = black_hole( Mb, r0, v0, acc, force )

tmax = 3
dt = 0.001
N = int(tmax/dt)
for i in xrange( N ):
    BHC1.time_step( dt=dt )
    if np.linalg.norm( BHC1.r )<0.01:
        break
        
rtc1 = np.array(BHC1.rt[:])
rmtc1 = np.linalg.norm( rtc1, axis=1 )
vtc1 = np.array(BHC1.vt[:])
vmtc1 = np.linalg.norm( vtc1, axis=1 )
tc1 = np.array(BHC1.time)

# %% [markdown]
# ## Drag friction force - overdamping

# %% [markdown]
# An effective drag friction force is defined here. For doing so, the potential is Taylor expanded at the center and an overdamping friction force is introduced, which would correspond to the minimal friction force that a perturber can experienced to avoid oscillation.
#
# $$ M_{BH}\frac{d \vec{v}_{BH}}{dt} = -\eta \frac{\vec{v}_{BH}}{t_{dyn}},\ \ \ \ \ \ t_{dyn} = \frac{1}{\sqrt{ 4\pi G \rho_{hern}( \vec{r} ) }} $$

# %%
#PARAMETERS OF DRAG FORCE
#Mass of black hole [1e10 M_sun]
Mb = 1e-2
#Friction coefficient
coef = 1.15

#Distribution function
hernquist.kargs = { 'coef':coef }

# %%
#PARAMETERS OF THE BH
#Initial position [kpc]
r0 = [ 2, 0, 0 ]
#Initial velocity [km/s]
v0 = [ 0, hernquist.v_circular(2), 0 ]
#Accretion mode
acc = None
#Forces
force = lambda r, v=None, t=None: hernquist.force_hernquist( r, v, t ) + hernquist.drag_friction( r, v, t )

BHD1 = black_hole( Mb, r0, v0, acc, force )

tmax = 3
dt = 0.001
N = int(tmax/dt)
for i in xrange( N ):
    BHD1.time_step( dt=dt )
    if np.linalg.norm( BHD1.r )<0.05:
        break
        
rtd1 = np.array(BHD1.rt[:])
rmtd1 = np.linalg.norm( rtd1, axis=1 )
vtd1 = np.array(BHD1.vt[:])
vmtd1 = np.linalg.norm( vtd1, axis=1 )
td1 = np.array(BHD1.time)

# %%
plt.figure( figsize=(16,8) )
plt.subplot(1,2,1)

#Analytic trajectories
plt.plot(rtc1[:,0], rtc1[:,1], '-', lw=2, color = 'red')


#Simulated trajectories
T = max_snap
plt.plot( bh_s16.r_c[:T,0], bh_s16.r_c[:T,1] , '.-', lw=2, color = 'black', zorder = 0 )

dL = 2.5
plt.xlim( (-dL,dL) )
plt.ylim( (-dL,dL) )
plt.xlabel( "$x$ [kpc]", fontsize = 18 )
plt.ylabel( "$y$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Orbit of the SMBH", fontsize = 18 )

plt.subplot(1,2,2)

#Analytic trajectories
plt.plot(rtd1[:,0], rtd1[:,1], '-', lw=2, color = 'blue')


#Simulated trajectories
T = max_snap
plt.plot( bh_s26.r_c[:T,0], bh_s26.r_c[:T,1] , '.-', lw=2, color = 'gray', zorder = 0 )

dL = 2.5
plt.xlim( (-dL,dL) )
plt.ylim( (-dL,dL) )
plt.xlabel( "$x$ [kpc]", fontsize = 18 )
plt.ylabel( "$y$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Orbit of the SMBH", fontsize = 18 )

# %%
plt.figure( figsize=(16,8) )

#Analytic trajectories
plt.plot(tc1, rmtc1, '-', lw=2, color = 'red', label = 'Chandrasekhar BH')
plt.plot(td1, rmtd1, '-', lw=2, color = 'blue', label = 'Drag BH')

#Simulated trajectories
plt.plot( bh_s16.t[:T], bh_s16.rm_c[:T], '-', lw=2, color = 'black', zorder = 10, label = 'hernq_kick_BH_1e6' )
plt.plot( bh_s26.t[:T], bh_s26.rm_c[:T], '-', lw=2, color = 'gray', zorder = 10, label = 'hernq_drag_BH_1e6' )

#plt.semilogx()
plt.ylim( (0,3) )
plt.xlim( (0,2) )
plt.xlabel( "$t$ [Gyr]", fontsize = 18 )
plt.ylabel( "$r$ [kpc]", fontsize = 18 )
plt.grid(1)
plt.title( "Distance to the center", fontsize = 18 )
leg = plt.legend( loc= 'upper right', fancybox = True )

# %% [markdown]
# - - -

# %% [markdown]
# # Tests

# %%
data = h5py.File( '/home/bustamsn/PhD/Data/hernquist_dynamical_friction/hernq_kick_BH_1e5/output/snapshot_240.hdf5', 'r')
coord = data['PartType1']['Coordinates']

# %%
np.array(data['PartType1']['Coordinates'])
# Out:
# array([[ 192.30810547,  288.70281982,   86.32121277],
#        [ 194.44038391,  294.50588989,   87.08820343],
#        [ 194.72692871,  305.7527771 ,   85.26747131],
#        ...,
#        [  50.31314087,  419.61929321,  410.26272583],
#        [  18.18054199,  465.5223999 ,  418.18252563],
#        [  96.94970703,  456.42053223,  432.79046631]], dtype=float32)

# %%
np.array(data['PartType1']['Coordinates']) - data['PartType5']['Coordinates'][0]
# Out:
# array([[ -59.97750854,   38.8505249 , -164.39854431],
#        [ -57.8452301 ,   44.65359497, -163.63156128],
#        [ -57.5586853 ,   55.90048218, -165.45228577],
#        ...,
#        [-201.97247314,  169.76699829,  159.54296875],
#        [-234.10507202,  215.67010498,  167.46276855],
#        [-155.33590698,  206.5682373 ,  182.07070923]], dtype=float32)

# %%
np.linalg.norm( np.array(data['PartType1']['Coordinates']) - data['PartType5']['Coordinates'][0], axis = 1 )
# Out:
# array([ 0.00557854,  0.00558013,  0.00543829, ...,  0.00324327,
#         0.00278033,  0.00316308], dtype=float32)

# %%
data['PartType5']['Coordinates'][0]
# Out:
# array([ 252.28561401,  249.85229492,  250.71975708], dtype=float32)

# %%
np.sqrt(coord[:,0]**2 + coord[:,1]**2 + coord[:,2]**2)
# Out:
# array([ 446.98394775,  444.85028076,  447.41867065, ...,  362.89382935,
#         660.78149414,  575.54187012], dtype=float32)

# %%
timeit np.linalg.norm( coord, axis=1 )
# Out:
# 1000 loops, best of 3: 1.35 ms per loop

# %%
np.sqrt(259*1.858e-4*430007.105732/2.)
# Out:
# 101.71747131996659

# %%
hernquist.v_circular(2)
# Out:
# 165.16033035802852

# %%
#Plotting bmax function
R = np.linspace( 1e-5,1000,100 )
Bmax = hernquist.bmax( R )
plt.plot( R, Bmax )
Bmin = np.array([hernquist.bmin(hernquist.v_circular(ri)) for ri in R])
plt.plot( R, Bmin )
plt.plot( R, R )
plt.loglog()
# Out:
# []

# %% [markdown]
# - - -
