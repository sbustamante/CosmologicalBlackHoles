# %% [markdown]
# # Analysis of Illustris

# %% [markdown]
# - - -

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Contents

# %% [markdown]
# - [General Functions](#General-Functions)

# %% [markdown]
# - - -

# %%
#==================================================================================================
#Importing all necessary libraries
#==================================================================================================
# %pylab inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import h5py

from matplotlib import animation
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Loading data

# %%
hdf5_file_name = '/home/bustamsn/PhD/CosmologicalBlackHoles/Data/isolated_galaxy_fix_BH/snapshot_020.hdf5'

# %% [markdown]
# **Table of data types**
#
# | Name          | Particle    | Color    |
# | ------------- | ----------- | -------- |
# | PartType0     | Gas         | Blue     |
# | PartType1     | DM          | Gray     |
# | PartType2     | Disk        | White    |
# | PartType3     | Bulge       | White    |
# | PartType4     | Stars       | Yellow   |
# | PartType5     | BH          | Red      |

# %%
datafile = h5py.File(hdf5_file_name, 'r')
data = []
#Position of gas particles
for i in xrange(6):
    data.append( np.array(datafile['PartType%d'%i]['Coordinates']) )
data = np.array(data)

# %% [markdown]
# ## Plotting galaxy

# %%
plt.figure( figsize = (18,9) )

#Colors
colors = [ "blue", "gray", "white", "white", "yellow", "red" ]
d_datas = [ 1, 1, 5, 5, 1, 1 ]
widths = [ 0.1, 0.05, 0.05, 0.05, 0.05, 8 ]
for i in xrange(6):
    d_data = d_datas[i]
    plt.subplot(1, 2, 1)
    plt.plot( data[i][::d_data,0], data[i][::d_data,1], ".", ms=widths[i], color=colors[i] )
    plt.subplot(1, 2, 2)
    plt.plot( data[i][::d_data,1], data[i][::d_data,2], ".", ms=widths[i], color=colors[i] )

#Fixing window limits
dx = 30
center = (500, 500)
for i in xrange(1,3):
    plt.subplot( 1, 2, i )
    plt.fill_between( (center[0]-dx,center[0]+dx), center[1]-dx,center[1]+dx, color = 'black' )
    plt.xlim( (center[0]-dx,center[0]+dx) )
    plt.ylim( (center[1]-dx,center[1]+dx) )
    plt.xlabel( "[$kpc$]", fontsize = 15 )
    plt.ylabel( "[$kpc$]", fontsize = 15 )
