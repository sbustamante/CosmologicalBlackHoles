# %% [markdown]
# # Black Holes in Illustris

# %% [markdown]
# - - -

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# - - -

# %%
#==================================================================================================
#Importing all necessary libraries
#==================================================================================================
# %pylab inline
import illustris_python as il
import matplotlib as mpl
from IPython.display import HTML
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation
import matplotlib.image as mpimg
import numpy as np
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
basePath = '/home/sebastian/Data/Simulations/Illustris3'

# %% [markdown]
# ### Spatial distribution

# %%
dm_pos = il.snapshot.loadSubset(basePath,135,'dm',['Coordinates']);
bh_pos = il.snapshot.loadSubset(basePath,135,'bh',['Coordinates'])

plt.figure( figsize=(8,8) )
plt.plot(bh_pos[:,0], bh_pos[:,1], ".", ms = 1)
plt.hist2d(dm_pos[:,0], dm_pos[:,1], norm=mpl.colors.LogNorm(), bins=512, cmap="hot");
plt.xlim([0,75000])
plt.ylim([0,75000])
plt.xlabel('x [ckpc/h]')
plt.ylabel('y [ckpc/h]')

# %% [markdown]
# ### Mass histogram

# %%
fields = ['BH_Mass']
BD_mass = il.snapshot.loadSubset(basePath,135,'bh',fields=fields)

# %%
HistM, Mbins = np.histogram( np.log10(1e10*BD_mass), bins = 100  )
plt.figure( figsize=(8,5) )
plt.semilogy( Mbins[:-1], HistM, lw = 3 )
plt.xlabel( "$\log_{10}(M_{BH})\ [M_{\odot}]$", fontsize = 14 )
plt.ylabel( "Number of BHs", fontsize = 12 )
plt.title( "Total mass of the black hole particles" )
plt.grid(1)

# %% [markdown]
# # Gas properties

# %%
fields = ['BH_Mdot', 'BH_Density','HostHaloMass']
bh = il.snapshot.loadSubset(basePath,135,'BHs',fields=fields)
bh_mdot = bh['BH_Mdot']
bh_rho = bh['BH_Density']
bh_hhmass = bh['HostHaloMass']

# %%
plt.figure( figsize = (8,8) )
plt.scatter( np.log10(1e10*bh_mdot), np.log10(bh_hhmass), marker='.', c=np.log10(bh_rho), lw = 0.0 )
plt.ylabel( "Host Halo Mass $[10^{10} M_{\odot}/h]$", fontsize = 14 )
plt.xlabel( "$\dot{M}_{BH}\ [(M_{\odot}/h)/(0.978 Gyr/h)^2]$", fontsize = 14 )
cbar = plt.colorbar()
cbar.set_label('BH density $[(10^{10}M_{\odot}/h)/(ckpc/h)^3]$', fontsize = 14 )

# %%
fields = ['BH_Mass','BH_Mdot', 'BH_Density','HostHaloMass']
BD_mass = il.snapshot.loadHalo(basePath,135,100,'bh',fields=fields)

# %%
np.sort(BD_mass["BH_Mass"])
# Out:
# array([  1.13234937e-05,   1.14884697e-05,   2.04628504e-05,
#          3.06016445e-05,   7.05039638e-05,   8.48250420e-05,
#          1.05256207e-04,   2.37623666e-04,   1.42313121e-03,
#          5.05271088e-03,   1.26784639e-02,   1.43725462e-02], dtype=float32)
